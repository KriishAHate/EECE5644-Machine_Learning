# %% [markdown]
# ### EDA

# %%
import pandas as pd
import numpy as np

# list of  weather underground files (add more  needed)
files = [
    "Weather underground data/Weather Underground East Boston Full 2023.csv",
    "Weather underground data/Weather Underground East Boston Full 2024.csv",
    "Weather underground data/Weather Underground East Boston Jan-Nov 2025.csv",
]

df_list = []

for file in files:
    df_raw = pd.read_csv(file, low_memory=False)
    print(f"Loaded {file} with shape {df_raw.shape}")
    
    # normalize fog column names just in case (even if we dont use them now)
    rename_dict = {}
    for col in df_raw.columns:
        col_norm = col.replace(" ", "").lower()
        if col_norm == "dew/tempfog?":
            rename_dict[col] = "Dew/Temp fog?"
        if col_norm == "rhfog?":
            rename_dict[col] = "RH fog?"
    if rename_dict:
        df_raw = df_raw.rename(columns=rename_dict)
    
    df_list.append(df_raw)

# single raw dataframe with all years
df_raw = pd.concat(df_list, ignore_index=True)

display(df_raw.head(3))
df_raw.shape
# Out:
# Loaded Weather underground data/Weather Underground East Boston Full 2023.csv with shape (48685, 15)
# Loaded Weather underground data/Weather Underground East Boston Full 2024.csv with shape (105349, 15)
# Loaded Weather underground data/Weather Underground East Boston Jan-Nov 2025.csv with shape (86508, 15)
#        Date     Time Temperature_C Dew_Point_C Humidity_%  Wind Speed_kmh  \
# 0  7/9/2023  8:17 PM         21.11       19.56         91  East     10.46
# 1  7/9/2023  8:31 PM         21.28       19.56         90   SSE      5.47
# 2  7/9/2023  8:50 PM         21.39        19.5         89  East      5.79
#
#   Gust_kmh Pressure_hPa Precip_Rate_mm Precip_Accum_mm UV Solar_w/m2  \
# 0    13.03      1011.18              0               0  0        1.6
# 1     11.1      1011.18              0               0  0        0.3
# 2    13.03      1011.18              0               0  0          0
#
#   Dew/Temp fog?  RH fog?
# 0             1        0
# 1             1        0
# 2             1        0
# (240542, 15)

# %%
# combine Date + Time into local Boston time
dt_str = df_raw["Date"].astype(str) + " " + df_raw["Time"].astype(str)
ts_local = pd.to_datetime(dt_str, errors="coerce")

# localize to America/New_York and convert to UTC
ts_utc = (
    ts_local
    .dt.tz_localize("America/New_York", ambiguous="NaT", nonexistent="NaT")
    .dt.tz_convert("UTC")
)

df_raw["timestamp_utc"] = ts_utc
df_raw = df_raw.dropna(subset=["timestamp_utc"]).copy()

# Choose only column required
df = df_raw[[
    "timestamp_utc",
    "Temperature_C",
    "Dew_Point_C",
    "Humidity_%",
    "Wind",
    "Speed_kmh",
    "Pressure_hPa",
    "Precip_Rate_mm",
    "Precip_Accum_mm",
    "Dew/Temp fog?",
    "RH fog?",
]].copy()

df.info()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_102884\1315111008.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ts_local = pd.to_datetime(dt_str, errors="coerce")
# <class 'pandas.core.frame.DataFrame'>
# Index: 240469 entries, 0 to 240541
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   timestamp_utc    240469 non-null  datetime64[ns, UTC]
#  1   Temperature_C    232727 non-null  object
#  2   Dew_Point_C      232727 non-null  object
#  3   Humidity_%       232727 non-null  object
#  4   Wind             236883 non-null  object
#  5   Speed_kmh        240469 non-null  object
#  6   Pressure_hPa     240469 non-null  object
#  7   Precip_Rate_mm   240469 non-null  object
#  8   Precip_Accum_mm  240469 non-null  object
#  9   Dew/Temp fog?    240469 non-null  object
#  10  RH fog?          240469 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(1), object(9)
# memory usage: 22.0+ MB

# %%
# ensure numeric typing for some required variables
columns = [
    "Temperature_C",
    "Dew_Point_C",
    "Humidity_%",
    "Speed_kmh",
    "Pressure_hPa",
    "Precip_Rate_mm",
    "Precip_Accum_mm",
    "Dew/Temp fog?",
    "RH fog?",
]

for col in columns:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240469 entries, 0 to 240541
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   timestamp_utc    240469 non-null  datetime64[ns, UTC]
#  1   Temperature_C    232727 non-null  float64
#  2   Dew_Point_C      232727 non-null  float64
#  3   Humidity_%       232727 non-null  float64
#  4   Wind             236883 non-null  object
#  5   Speed_kmh        240469 non-null  float64
#  6   Pressure_hPa     240469 non-null  float64
#  7   Precip_Rate_mm   240469 non-null  float64
#  8   Precip_Accum_mm  240469 non-null  float64
#  9   Dew/Temp fog?    232727 non-null  float64
#  10  RH fog?          240469 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(8), int64(1), object(1)
# memory usage: 22.0+ MB

# %% [markdown]
# ### Resampling
# This dataset is not at hourly resolution, so we need to resample it to hourly resolution.

# %%
# set index for resampling
df = df.set_index("timestamp_utc").sort_index()

# aggregate to hourly resolution
hourly = (
    df
    .resample("5T")
    .agg({
        "Temperature_C": "mean",
        "Dew_Point_C": "mean",
        "Humidity_%": "mean",
        "Speed_kmh": "mean",
        "Pressure_hPa": "mean",
        "Precip_Rate_mm": "mean", 
        "Precip_Accum_mm": "max", # this is cumulative; hourly max is a dumb down
        "Wind": "last", # wind direction is categorical; we take the last observation in the hour for now, change later if needed
        "Dew/Temp fog?": "max",
        "RH fog?": "max",
    })
    .reset_index()
)
print(hourly.shape)
hourly.head()
# Out:
# (247161, 11)
# C:\Users\USER\AppData\Local\Temp\ipykernel_102884\3370112273.py:7: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   .resample("5T")
#               timestamp_utc  Temperature_C  Dew_Point_C  Humidity_%  \
# 0 2023-07-10 00:15:00+00:00          21.11        19.56        91.0
# 1 2023-07-10 00:20:00+00:00            NaN          NaN         NaN
# 2 2023-07-10 00:25:00+00:00            NaN          NaN         NaN
# 3 2023-07-10 00:30:00+00:00          21.28        19.56        90.0
# 4 2023-07-10 00:35:00+00:00            NaN          NaN         NaN
#
#    Speed_kmh  Pressure_hPa  Precip_Rate_mm  Precip_Accum_mm  Wind  \
# 0      10.46       1011.18             0.0              0.0  East
# 1        NaN           NaN             NaN              NaN  None
# 2        NaN           NaN             NaN              NaN  None
# 3       5.47       1011.18             0.0              0.0   SSE
# 4        NaN           NaN             NaN              NaN  None
#
#    Dew/Temp fog?  RH fog?
# 0            1.0      0.0
# 1            NaN      NaN
# 2            NaN      NaN
# 3            1.0      0.0
# 4            NaN      NaN

# %%
hourly.to_csv("Filtered dataset/Weather_Underground_5min_East_Boston_full.csv", index=False)
